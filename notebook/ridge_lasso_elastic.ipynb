# %% [markdown]
# ## Algerian Forest Fires Dataset
# Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012.
# The dataset includes 11 attribues and 1 output attribue (class)
# The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.

# %% [markdown]
# Attribute Information:
#
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
# Weather data observations
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# 3. RH : Relative Humidity in %: 21 to 90
# 4. Ws :Wind speed in km/h: 6 to 29
# 5. Rain: total day in mm: 0 to 16.8
# FWI Components
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68
# 11. Fire Weather Index (FWI) Index: 0 to 31.1
# 12. Classes: two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header=1)
# heade r=1 From row 1, Row 0 skipped, row 1 = column names

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
# dtypes: str(14)
# memory usage: 27.0 KB

# %% [markdown]
# #### Data Cleaning Process
#
# Here every columns are object/str . Need to cconvert those are supposed to be numericcal form.

# %%
## Missing values 
dataset.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
dataset[dataset.isnull().any(axis=1)]
# axis=1 → row-wise
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index, we can make a new column based on the Region
#
# 1 : "Bejaia Region Dataset"
#
# 2 : "Sidi-Bel Abbes Region Dataset"
#
# Add new column with region

# %%
# Create a new column called 'Region' in the dataset

# For rows from index 0 to 122 (inclusive),
# assign Region = 0 → representing "Bejaia Region Dataset"
dataset.loc[:122, "Region"] = 0  

# For rows from index 122 to the end,
# assign Region = 1 → representing "Sidi-Bel Abbes Region Dataset"
dataset.loc[122:, "Region"] = 1
df = dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    str
#  1   month        245 non-null    str
#  2   year         245 non-null    str
#  3   Temperature  245 non-null    str
#  4    RH          245 non-null    str
#  5    Ws          245 non-null    str
#  6   Rain         245 non-null    str
#  7   FFMC         245 non-null    str
#  8   DMC          245 non-null    str
#  9   DC           245 non-null    str
#  10  ISI          245 non-null    str
#  11  BUI          245 non-null    str
#  12  FWI          245 non-null    str
#  13  Classes      244 non-null    str
#  14  Region       246 non-null    float64
# dtypes: float64(1), str(14)
# memory usage: 29.0 KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
## Removing l values 
# index 122 and 167 contains null values
# Drop rows with NaN and reset index to clean numbering (0,1,2,...)
# drop=True → do not keep old index as a new column
df=df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
##remove the 122nd row
df = df.drop(122).reset_index(drop=True)

# %%
# Cheking again 
# The header has been deleted
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='str')

# %%
# Fix spaces in columns name
# There is spcae after column name Classes
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='str')

# %% [markdown]
# #### Changes the required columns as integer data type

# %%
df[['day', 'month', 'year', 'Temperature', 'RH']] = df[['day', 'month', 'year', 'Temperature', 'RH']].astype(int)

# %%
# Cheking 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    str
#  6   Rain         243 non-null    str
#  7   FFMC         243 non-null    str
#  8   DMC          243 non-null    str
#  9   DC           243 non-null    str
#  10  ISI          243 non-null    str
#  11  BUI          243 non-null    str
#  12  FWI          243 non-null    str
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: int64(6), str(9)
# memory usage: 28.6 KB

# %% [markdown]
# #### Changes the required columns as float data type

# %%
# We ca do it as 
df[['Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
## Generic way to do that 
# objects=[features for features in df.columns if df[features].dtypes=='O']

# %%
# print(objects)

# %%
# for i in objects:
#     if i!='Classes':
#         df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    str
#  14  Region       243 non-null    int64
# dtypes: float64(8), int64(6), str(1)
# memory usage: 28.6 KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
  ## Let's have the cleaned dataset
df.to_csv('Algerian_forest_fires_cleaned_dataset.csv',index=False)

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
## drop day,month and year
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## Encoding of the categories in classes
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'), 0, 1)

# %%
# Classes column is not clean
# "not fire"
# "fire"
# "not fire   "
# " fire"

# Thats why instaed of df_copy['Classes'] = np.where(df_copy['Classes']=='not fire',0,1) we are using .str.contains()

# %%
df_copy.head()
# Out:
#    Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# But there are many numbers of zeros, here only appearing just 2 so something is wrong.abs
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df_copy.head()
# Out:
#    Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
## Plot desnity plot for all features
sns.set_style('whitegrid')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()

# %%
## Percentage for Pie Chart 
percentage = df_copy['Classes'].value_counts(normalize=True)*100
# normalize=True does this internally: count / total_rows

# %%
# plotting piechart
classlabels = ["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%') # Use %% because % is a formatting symbol
plt.title("Pie Chart of Classes")
plt.show()

# %%
## Correlation 
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <Axes: >

# %%
## Box plot 
sns.boxplot(x=df_copy['FWI'],color='yellow')
# Out:
# <Axes: xlabel='FWI'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
## Monthly fire analysis 
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=dftemp)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi- Bel Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Sidi- Bel Regions')

# %%
## Monthly Fire Analysis
dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Brjaia Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Brjaia Regions')

# %% [markdown]
# Its observed that August and September had the most number of forest fires for both regions. And from the above plot of months, we can understand few things
#
# Most of the fires happened in August and very high Fires happened in only 3 months - June, July and August.
#
# Less Fires was on September
